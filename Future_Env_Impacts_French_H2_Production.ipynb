# %% [markdown]
# <div>
#     <table>
#         <tr>
#             <td>
#                 <center>
#                     <h1>Future environmental impacts of French hydrogen
# production </h1>
#                     <br><br>
#                     This work is an adaption of the work from Guillaume Batôt (ACTiON 2024) - modeling the future French Electricity Mix - and from the work of S. Wei et al. 2024 (https://doi.org/10.1039/D3EE03875K  )
#                 </center>
#             </td>
#         </tr>
#     </div>

# %%
from premise import *
from premise_gwp import add_premise_gwp

# %%
import bw2data as bd
import bw2io as bi
import bw2calc as bc

# print(bd.__version__)
# print(bi.__version__)
# print(bc.__version__)

# %%
# bd.projects.copy_project("pLCA_H2_N03_-10%SMR_v3", switch=True)

# %%
# list(bd.projects)
# Out:
# [Project: default,
#  Project: bw25_intro,
#  Project: Temporalis example project,
#  Project: bw_temporalis example,
#  Project: odym,
#  Project: dds-MFA,
#  Project: pLCA_H2,
#  Project: H2_GWP,
#  Project: wei2024_test,
#  Project: Elegancy,
#  Project: H2_produciton_ei3.9.1,
#  Project: H2ValueChain,
#  Project: ecoinvent3.11,
#  Project: pLCA_H2_M23,
#  Project: pLCA_M23-LB_H2,
#  Project: pLCA_H2_N03,
#  Project: pLCA_M23_wLeakage,
#  Project: pLCA_H2_N03_v2,
#  Project: pLCA_H2_M23_v2,
#  Project: pLCA_new,
#  Project: pLCA_new2,
#  Project: bw25_test,
#  Project: pLCA_ei311,
#  Project: Brightway regional tutorial,
#  Project: pLCA_H2_N03_v3,
#  Project: pLCA_H2_M23_v3,
#  Project: pLCA_H2_M23_-10%SMR_v3,
#  Project: pLCA_H2_N03_-10%SMR_v3]

# %%
bd.projects.set_current("pLCA_H2_N03_v3") # Adapt with the name of your project
# Make sure that you have imported ecoinvent 3.11 cut-off and the corresponding biosphere

# bi.bw2setup()
# add_premise_gwp()

# %%
bd.databases
# Out:
# Databases dictionary with 8 object(s):
# 	N03_LB-H2_TIAM-UCL_SSP2-RCP45_2025
# 	N03_LB-H2_TIAM-UCL_SSP2-RCP45_2030
# 	N03_LB-H2_TIAM-UCL_SSP2-RCP45_2035
# 	N03_UB-H2_TIAM-UCL_SSP2-RCP45_2025
# 	N03_UB-H2_TIAM-UCL_SSP2-RCP45_2030
# 	N03_UB-H2_TIAM-UCL_SSP2-RCP45_2035
# 	biosphere3
# 	ecoinvent-3.11-cutoff

# %%
# del bd.databases['N03_UB-H2_TIAM-UCL_SSP2-RCP45_2025test']
# Out:
# Vacuuming database

# %% [markdown]
# ### Generate Prospective Database

# %%
from datapackage import Package

# import gc
# gc.collect()


fp = "datapackage_attributional.json" # Or adapt with your the file path

h2 = Package(fp)
h2.resource_names

scenario = "N03_UB-H2" # should be written the same as in scenario data, configuration and .json file and 
model = "TIAM-UCL"
pathway = "SSP2-RCP45"

external_scenario = [
    {"scenario": scenario , "data": h2}
]

for year in [2025] :#[2025, 2030, 2035]: # The more the number of years the more the memory needed to fully complete the loop
    print(year)

    scenarios = [
        {"model": model, "pathway":pathway, "year": year, "external scenarios": external_scenario},
    ]

    ndb = NewDatabase(
        scenarios = scenarios,        
        source_db="ecoinvent-3.11-cutoff",
        source_version="3.11",
        #key='xxx',
        key='tUePmX_S5B8ieZkkM7WUU2CnO8SmShwmAeWK9x2rTFo=',
        quiet = True,
    )
    #ndb.generate_scenario_report()
    
    ndb.update(["electricity", # integrate IAM projections
                "external"]) # integrate custom scenario projections on top of it
#    ndb.write_db_to_brightway(scenario+'_'+model+'_'+pathway+'_'+str(year)+'_test_ei.311')
#     gc.collect()
    ndb.write_db_to_brightway(scenario+'_'+model+'_'+pathway+'_'+str(year)+'bis')

# gc.collect()
# Out:
# 2025
# - Extracting source database
# - Extracting inventories
# - Fetching IAM data
# Found file: tiam-ucl_SSP2-RCP45
# Reading tiam-ucl_SSP2-RCP45 as CSV file
# Done!
# Processing scenarios for 2 sectors:   0%|       | 0/1 [00:07<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 38
#      28     ndb = NewDatabase(
#      29         scenarios = scenarios,
#      30         source_db="ecoinvent-3.11-cutoff",
#    (...)
#      34         quiet = True,
#      35     )
#      36     #ndb.generate_scenario_report()
# ---> 38     ndb.update(["electricity", # integrate IAM projections
#      39                 "external"]) # integrate custom scenario projections on top of it
#      40 #    ndb.write_db_to_brightway(scenario+'_'+model+'_'+pathway+'_'+str(year)+'_test_ei.311')
#      41 #     gc.collect()
#      42     ndb.write_db_to_brightway(scenario+'_'+model+'_'+pathway+'_'+str(year)+'bis')
#
# File ~\AppData\Local\anaconda3\envs\premise_new\lib\site-packages\premise\new_database.py:1027, in NewDatabase.update(self, sectors)
#    1024 for scenario in self.scenarios:
#    1025     # add database to scenarios
#    1026     try:
# -> 1027         scenario = load_database(
#    1028             scenario=scenario,
#    1029             original_database=self.database,
#    1030             load_metadata=False,
#    1031             warning=False,
#    1032         )
#    1033     except KeyError:
#    1034         scenario["database"] = pickle.loads(pickle.dumps(self.database, -1))
#
# File ~\AppData\Local\anaconda3\envs\premise_new\lib\site-packages\premise\utils.py:410, in load_database(scenario, original_database, delete, load_metadata, warning)
#     408     if warning:
#     409         print("WARNING: loading unmodified database!")
# --> 410     scenario["database"] = pickle.loads(pickle.dumps(original_database, -1))
#     412 else:
#     413     filepath = scenario["database filepath"]
#
# KeyboardInterrupt:
